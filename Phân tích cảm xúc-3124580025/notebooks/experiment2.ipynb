# %% [markdown]
# # Thử nghiệm 2: So sánh ba mô hình học máy Logistic Regression, Naive Bayes và SVM và ta sẽ sử dụng kỹ thuật tìm siêu tham số (hyperparameters) cho mô hình tốt nhất

# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("../data/processed/IMDB Processed.csv")

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df["review"],
    df["sentiment"],
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ### Load Term Frequency-Inverse Document Frequency model (TFIDF)

# %%
tfidf = joblib.load("../models/tfidf.pkl")

# %%
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %% [markdown]
# ### Logistic Regression

# %%
lr_model = LogisticRegression( max_iter=1000, solver="liblinear", C=1.0)
lr_model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
print("Train accuracy:", lr_model.score(X_train_tfidf, y_train))
print("Test accuracy:", lr_model.score(X_test_tfidf, y_test))
# Out:
# Train accuracy: 0.9422369018203822
# Test accuracy: 0.9013715207745059

# %%
lr_pred = lr_model.predict(X_test_tfidf)

# %%
joblib.dump(lr_model, "../models/lr_model.pkl")
# Out:
# ['../models/lr_model.pkl']

# %% [markdown]
# ### Naive Bayes

# %%
nb_model = MultinomialNB(alpha = 1.0)
nb_model.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
print("Train accuracy:", nb_model.score(X_train_tfidf, y_train))
print("Test accuracy:", nb_model.score(X_test_tfidf, y_test))
# Out:
# Train accuracy: 0.9152841510765972
# Test accuracy: 0.8807987091569182

# %%
nb_pred = nb_model.predict(X_test_tfidf)

# %%
joblib.dump(nb_model, "../models/nb_model.pkl")
# Out:
# ['../models/nb_model.pkl']

# %% [markdown]
# ### Linear SVM

# %%
svm_model = LinearSVC(C = 0.1)
svm_model.fit(X_train_tfidf, y_train)
# Out:
# LinearSVC(C=0.1)

# %%
print("Train accuracy:", svm_model.score(X_train_tfidf, y_train))
print("Test accuracy:", svm_model.score(X_test_tfidf, y_test))
# Out:
# Train accuracy: 0.9455145983561091
# Test accuracy: 0.9020774505849133

# %%
svm_pred = svm_model.predict(X_test_tfidf)

# %%
joblib.dump(svm_model, "../models/svm_model.pkl")
# Out:
# ['../models/svm_model.pkl']

# %% [markdown]
# ### So sánh

# %%
lr_acc = accuracy_score(y_test, lr_pred)
nb_acc = accuracy_score(y_test, nb_pred)
svm_acc = accuracy_score(y_test, svm_pred)
# Model Comparison Summary
print("\n===== COMPARISON =====")
print(f"Logistic Regression: {lr_acc*100:.2f}%")
print(f"Naive Bayes: {nb_acc*100:.2f}%")
print(f"SVM: {svm_acc*100:.2f}%")
# Out:
# ===== COMPARISON =====
# Logistic Regression: 90.14%
# Naive Bayes: 88.08%
# SVM: 90.21%

# %% [markdown]
# Vì SVM có chỉ số cao nhất nên ta sẽ sử dụng kỹ thuật tìm siêu tham số (hyperparameters) tốt nhất

# %%
svm = joblib.load("../models/svm_model.pkl")

# %%
# Hyperparameter Tuning (GridSearch for SVM)
param_grid = {
    'C': [0.1, 1, 10, 100],
    'loss': ['hinge', 'squared_hinge']
}

grid = GridSearchCV(svm, param_grid, refit=True, verbose=2)
grid.fit(X_train_tfidf, y_train)

print("Best CV Score: {:.2f}".format(grid.best_score_))
print("Best Parameters:", grid.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.3s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.2s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.2s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.2s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.2s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ....................................C=1, loss=hinge; total time=   0.7s
# [CV] END ....................................C=1, loss=hinge; total time=   0.6s
# [CV] END ....................................C=1, loss=hinge; total time=   0.8s
# [CV] END ....................................C=1, loss=hinge; total time=   3.6s
# [CV] END ....................................C=1, loss=hinge; total time=   0.6s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.6s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.6s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.6s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.6s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.6s
# [CV] END ...................................C=10, loss=hinge; total time=   3.7s
# [CV] END ...................................C=10, loss=hinge; total time=   2.1s
# [CV] END ...................................C=10, loss=hinge; total time=   3.4s
# c:\Users\Administrator\Downloads\sentiment-analysis\venv\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV] END ...................................C=10, loss=hinge; total time=  11.1s
# [CV] END ...................................C=10, loss=hinge; total time=   2.1s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   3.1s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   2.3s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   2.5s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   2.8s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   1.9s
# [CV] END ..................................C=100, loss=hinge; total time=   4.7s
# [CV] END ..................................C=100, loss=hinge; total time=   3.5s
# [CV] END ..................................C=100, loss=hinge; total time=   3.4s
# c:\Users\Administrator\Downloads\sentiment-analysis\venv\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV] END ..................................C=100, loss=hinge; total time=  11.5s
# [CV] END ..................................C=100, loss=hinge; total time=   2.5s
# c:\Users\Administrator\Downloads\sentiment-analysis\venv\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV] END ..........................C=100, loss=squared_hinge; total time=  11.4s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   2.9s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   7.2s
# [CV] END ..........................C=100, loss=squared_hinge; total time=  10.5s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   2.3s
# Best CV Score: 0.91
# Best Parameters: {'C': 1, 'loss': 'hinge'}

# %%
# Train Final Optimized SVM
best_svc = LinearSVC(C=grid.best_params_['C'], loss=grid.best_params_['loss'])
best_svc.fit(X_train_tfidf, y_train)

best_pred = best_svc.predict(X_test_tfidf)
best_acc = accuracy_score(y_test, best_pred)

print("Optimized SVM Accuracy: {:.2f}%".format(best_acc * 100))

print(confusion_matrix(y_test, best_pred))
print("\n", classification_report(y_test, best_pred))
print("Train accuracy:", best_svc.score(X_train_tfidf, y_train))
print("Test accuracy:", best_svc.score(X_test_tfidf, y_test))
# Out:
# Optimized SVM Accuracy: 90.22%
# [[4358  524]
#  [ 446 4588]]
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4882
#            1       0.90      0.91      0.90      5034
#
#     accuracy                           0.90      9916
#    macro avg       0.90      0.90      0.90      9916
# weighted avg       0.90      0.90      0.90      9916
#
# Train accuracy: 0.9735262972114367
# Test accuracy: 0.9021782977006858

# %%
# Model Comparison Summary
print("\n===== FINAL COMPARISON =====")
print(f"Logistic Regression: {lr_acc*100:.2f}%")
print(f"Naive Bayes: {nb_acc*100:.2f}%")
print(f"SVM: {svm_acc*100:.2f}%")
print(f"Optimized SVM: {best_acc*100:.2f}%")
# Out:
# ===== FINAL COMPARISON =====
# Logistic Regression: 90.14%
# Naive Bayes: 88.08%
# SVM: 90.21%
# Optimized SVM: 90.22%

# %%
lr_train_acc = lr_model.score(X_train_tfidf, y_train)
nb_train_acc = nb_model.score(X_train_tfidf, y_train)
svm_train_acc = svm_model.score(X_train_tfidf, y_train)
best_train_acc = best_svc.score(X_train_tfidf, y_train)

models = ['Logistic Regression', 'Naive Bayes', 'SVM', 'Optimized SVM']

train_accuracy = [lr_train_acc, nb_train_acc, svm_train_acc, best_train_acc]
test_accuracy  = [lr_acc, nb_acc, svm_acc, best_acc]

x = np.arange(len(models))
width = 0.35

plt.figure(figsize=(10,6))

bars1 = plt.bar(x - width/2, train_accuracy, width, label='Train Accuracy')
bars2 = plt.bar(x + width/2, test_accuracy,  width, label='Test Accuracy')

def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height,
                 f'{height:.4f}',
                 ha='center', va='bottom',
                 fontsize=11, fontweight='bold')

add_labels(bars1)
add_labels(bars2)

plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Train vs Test Accuracy Comparison - Experiment 2')
plt.xticks(x, models)
plt.legend()

plt.ylim(0, 1.5)

plt.tight_layout()
plt.show()

# %%
joblib.dump(best_svc, '../models/best_svm_model.pkl')
# Out:
# ['../models/best_svm_model.pkl']

# %%
def evaluate_model(name, y_test, y_pred, train_time):
    report = classification_report(y_test, y_pred, output_dict=True)
    
    return {
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": report["weighted avg"]["precision"],
        "Recall": report["weighted avg"]["recall"],
        "F1-score": report["weighted avg"]["f1-score"],
        "Train time (s)": train_time
    }

# %%
import time

# Logistic Regression
start = time.time()
lr_model.fit(X_train_tfidf, y_train)
time_logreg = time.time() - start
logreg_pred = lr_model.predict(X_test_tfidf)

# Naive Bayes
start = time.time()
nb_model.fit(X_train_tfidf, y_train)
time_mnb = time.time() - start
mnb_pred = nb_model.predict(X_test_tfidf)

# SVM
start = time.time()
svm_model.fit(X_train_tfidf, y_train)
time_svc = time.time() - start
svc_pred = svm_model.predict(X_test_tfidf)

# GridSearch SVM
start = time.time()
grid.fit(X_train_tfidf, y_train)
time_best_svm = time.time() - start
best_svc = grid.best_estimator_
best_pred = best_svc.predict(X_test_tfidf)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.2s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.2s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.1s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.1s
# [CV] END ..................................C=0.1, loss=hinge; total time=   0.1s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ..........................C=0.1, loss=squared_hinge; total time=   0.3s
# [CV] END ....................................C=1, loss=hinge; total time=   2.1s
# [CV] END ....................................C=1, loss=hinge; total time=   0.8s
# [CV] END ....................................C=1, loss=hinge; total time=   1.5s
# [CV] END ....................................C=1, loss=hinge; total time=   5.4s
# [CV] END ....................................C=1, loss=hinge; total time=   0.9s
# [CV] END ............................C=1, loss=squared_hinge; total time=   1.1s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.9s
# [CV] END ............................C=1, loss=squared_hinge; total time=   1.1s
# [CV] END ............................C=1, loss=squared_hinge; total time=   1.0s
# [CV] END ............................C=1, loss=squared_hinge; total time=   0.8s
# [CV] END ...................................C=10, loss=hinge; total time=   4.2s
# [CV] END ...................................C=10, loss=hinge; total time=   1.9s
# [CV] END ...................................C=10, loss=hinge; total time=   2.7s
# c:\Users\Administrator\Downloads\sentiment-analysis\venv\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV] END ...................................C=10, loss=hinge; total time=  11.0s
# [CV] END ...................................C=10, loss=hinge; total time=   1.7s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   2.8s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   1.9s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   2.2s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   2.2s
# [CV] END ...........................C=10, loss=squared_hinge; total time=   1.9s
# [CV] END ..................................C=100, loss=hinge; total time=   4.6s
# [CV] END ..................................C=100, loss=hinge; total time=   3.0s
# [CV] END ..................................C=100, loss=hinge; total time=   2.4s
# c:\Users\Administrator\Downloads\sentiment-analysis\venv\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV] END ..................................C=100, loss=hinge; total time=  10.8s
# [CV] END ..................................C=100, loss=hinge; total time=   2.4s
# c:\Users\Administrator\Downloads\sentiment-analysis\venv\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV] END ..........................C=100, loss=squared_hinge; total time=  11.0s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   3.0s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   4.6s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   7.6s
# [CV] END ..........................C=100, loss=squared_hinge; total time=   2.7s

# %%
results = []

results.append(evaluate_model("Logistic Regression", y_test, logreg_pred, time_logreg))
results.append(evaluate_model("Naive Bayes", y_test, mnb_pred, time_mnb))
results.append(evaluate_model("SVM (LinearSVC)", y_test, svc_pred, time_svc))
results.append(evaluate_model("Best SVM (GridSearch)", y_test, best_pred, time_best_svm))

df_results = pd.DataFrame(results)
df_results
# Out:
#                    Model  Accuracy  Precision    Recall  F1-score  \
# 0    Logistic Regression  0.901372   0.901549  0.901372  0.901341
# 1            Naive Bayes  0.880799   0.880839  0.880799  0.880782
# 2        SVM (LinearSVC)  0.902077   0.902259  0.902077  0.902047
# 3  Best SVM (GridSearch)  0.902178   0.902254  0.902178  0.902160
#
#    Train time (s)
# 0        1.579167
# 1        0.031262
# 2        0.435400
# 3      109.248789

# %%
labels = ["Negative", "Positive"]  # hoặc theo thứ tự label của bạn

cm_logreg = confusion_matrix(y_test, logreg_pred)
cm_nb = confusion_matrix(y_test, mnb_pred)
cm_svm = confusion_matrix(y_test, svc_pred)
cm_best = confusion_matrix(y_test, best_pred)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

ConfusionMatrixDisplay(cm_logreg, display_labels=labels).plot(ax=axes[0,0], values_format='d')
axes[0,0].set_title("Logistic Regression")

ConfusionMatrixDisplay(cm_nb, display_labels=labels).plot(ax=axes[0,1], values_format='d')
axes[0,1].set_title("Naive Bayes")

ConfusionMatrixDisplay(cm_svm, display_labels=labels).plot(ax=axes[1,0], values_format='d')
axes[1,0].set_title("SVM (LinearSVC)")

ConfusionMatrixDisplay(cm_best, display_labels=labels).plot(ax=axes[1, 1], values_format='d')
axes[1, 1].set_title("Best SVM (GridSearch)")

cm_logreg = confusion_matrix(y_test, logreg_pred, normalize='true')

for ax in axes.ravel():
    for text in ax.texts:
        text.set_fontsize(16)

plt.tight_layout()
plt.show()

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def process(text):
    text = text.lower()
    text = re.sub('<br />', '', text)
    text = re.sub(r"http\S+|www\S+", '', text)

    text = text.replace("n't", " not")

    text = re.sub(r"[^\w\s]", '', text)

    tokens = word_tokenize(text)

    keep_words = {
        'not','no','nor','never','without',
        'but','however','although','though','yet',
        'very','too','so','really','extremely','absolutely',
        'hardly','barely','rarely','seldom'
    }

    stop_words = set(stopwords.words('english')) - keep_words

    tokens = [
        lemmatizer.lemmatize(w)
        for w in tokens
        if w not in stop_words
    ]

    return " ".join(tokens)

# %%
while True:
    review = input("Nhập review (gõ 'exit' để thoát): ")
    
    if review.lower() == 'exit':
        break
    
    try:
        review_processed = process(review)
    except:
        review_processed = review.lower()
    
    vec = tfidf.transform([review_processed])
    pred = nb_model.predict(vec)[0]
    
    if pred == 1:
        print(review, ": Positive")
    else:
        print(review, ": Negative ")
# Out:
# I really enjoyed this movie, the story was very engaging and the acting was excellent. : Positive
# Small story yet very powerful message. : Positive
# I do not like this movie, it is very boring and too long. : Negative
# The acting was bad and the story was even worse. : Negative
# Without the music, it is boring. : Negative
# I rarely see a movie this bad. : Negative
# Not good. : Negative
